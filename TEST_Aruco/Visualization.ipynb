# %%
import os
import pandas
import numpy
import matplotlib.pyplot as plt
import plotly.express as px

# %%
CWD = os.getcwd()
sorted(os.listdir(CWD))
# Out:
# ['.ipynb_checkpoints',
#  '200727_board_dyn100.avi',
#  '200727_board_dyn20.avi',
#  '200727_board_dyn60.avi',
#  '200727_board_static.avi',
#  '200727_charuco_3344_5_filtered_dyn100.avi',
#  '200727_charuco_3344_5_filtered_dyn20.avi',
#  '200727_charuco_3344_5_filtered_dyn60.avi',
#  '200727_charuco_3344_5_filtered_prev_dyn100.avi',
#  '200727_charuco_3344_5_filtered_prev_dyn20.avi',
#  '200727_charuco_3344_5_filtered_prev_dyn60.avi',
#  '200727_charuco_3344_5_filtered_prev_static.avi',
#  '200727_charuco_3344_5_filtered_static.avi',
#  '200727_charuco_3344_dyn100.avi',
#  '200727_charuco_3344_dyn20.avi',
#  '200727_charuco_3344_dyn60.avi',
#  '200727_charuco_3344_static.avi',
#  '200727_charuco_3344_test.avi',
#  '200727_charuco_3377_dyn100.avi',
#  '200727_charuco_3377_dyn20.avi',
#  '200727_charuco_3377_dyn60.avi',
#  '200727_charuco_3377_static.avi',
#  '200727_charuco_3377_test.avi',
#  '200727_charuco_dyn100.avi',
#  '200727_charuco_dyn20.avi',
#  '200727_charuco_dyn60.avi',
# ...

# %%
pose_file = 'poses_charuco_3344_5_filtered_prev_dyn100.ftr'
frame_file = 'frames_charuco_3344_5_filtered_prev_dyn100.ftr'

poses_df = pandas.read_feather(os.path.join(*[CWD, pose_file]))
frames_df = pandas.read_feather(os.path.join(*[CWD, frame_file]))

# %%
plot = poses_df.plot(subplots=True, figsize=(30,30), grid=True, legend=True, fontsize=18)
plot[0].figure.savefig(os.path.join(*[CWD, "plots", "{}.png".format(pose_file.split(".")[0])]))

# %%
# ?pandas.DataFrame.plot
# Out:
# Object `pandas.DataFrame.plot` not found.
