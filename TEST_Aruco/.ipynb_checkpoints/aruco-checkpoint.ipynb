# %% [markdown]
# # Description

# %% [markdown]
# Script for doing pose estimation using Intel RealSense D435i, ROS Melodic, OpenCV and ArUco markers

# %% [markdown]
# # Imports

# %%
import os
import numpy
import cv2
from cv_bridge import CvBridge
from cv_bridge.boost.cv_bridge_boost import getCvType

import rospy
from sensor_msgs.msg import Image, CameraInfo
from realsense2_camera.msg import EstimatedPose

# %% [markdown]
# # Functions

# %% [markdown]
# OpenCV Functions

# %%
def create_marker(config, marker_index):
    return cv2.aruco.drawMarker(config, marker_index, 600,0)

def create_board(config, marker_index):
    '''Creates a aruco board with the given configuration'''
    return cv2.aruco.GridBoard_create(config["markersX"], config["markersY"], config["markerLength"], config["markerSeparation"], config["dictionary"], marker_index)

def create_boards(config):
    '''Creates all four aruco boards and returns a list of them'''
    boards = []
    marker_index = 0
    board_index = 0
   
    for board_index in range(4):
        aruco_board = create_board(config, marker_index)
        boards.append(aruco_board)
        marker_index += 4
    return boards

def create_charuco_board(config):
    '''Creates a charuco board with the given configuration'''
    return cv2.aruco.CharucoBoard_create(config["squaresX"], config["squaresY"], config["squareLength"], config["markerLength"], config["dictionary"])

def create_charuco_boards(config):
    '''Creates four charuco boards and return a list of them'''
    charuco_boards = []
    board_index = 0
    
    for board_index in range(4):
        charuco_board = create_charuco_board(config)
        charuco_boards.append(charuco_board)
    
    return charuco_boards

def detect_marker(cv_image):
    '''Detects aruco marker on the given image'''
    aruco_dictionary = cv2.aruco.Dictionary_get(cv2.aruco.DICT_7X7_50)
    markers, ids, _ = cv2.aruco.detectMarkers(cv_image, aruco_dictionary)
    cv2.aruco.drawDetectedMarkers(cv_image, corners=markers,ids=ids, borderColor=150)
    cv2.imshow("Aruco Window", cv_image)
    return cv_image
    
def marker_pose_estimation(cv_image):
    '''6DoF Pose estimation of the detected aruco markers'''
    markers, ids, _ = cv2.aruco.detectMarkers(cv_image, marker_config)
    print(ids)
    if ids is not None:
    #if ids.size > 0:
        print("if ids is not None")
        cv2.aruco.drawDetectedMarkers(cv_image, corners=markers, ids=ids, borderColor=150)
        rotation_vector, translation_vector, valid = cv2.aruco.estimatePoseSingleMarkers(markers, 0.06, camera_matrix, distortion_coefficients, None, None)
        translation_vector += [-0.03,0.03,0]
        for marker in markers:
            print("for marker in markers")
        #if valid > 0:
            #rotation_vector, translation_vector, _ = cv2.aruco.estimatePoseSingleMarkers(marker, board_config["markerLength"], camera_matrix, distortion_coefficients, None, None)
            cv2.aruco.drawAxis(cv_image, cameraMatrix=camera_matrix, distCoeffs=distortion_coefficients, rvec=rotation_vector, tvec=translation_vector, length=0.03)#board_config["markerLength"])
            cv2.imshow("Stream", cv_image)
            return rotation_vector, translation_vector
    else:
        print("else")
        cv2.imshow("Stream", cv_image)
        return numpy.zeros(3), numpy.zeros(3)
    #out.write(cv_image)

def board_pose_estimation(cv_image):
    '''Does Board pose estimation'''
    markers, ids, _ = cv2.aruco.detectMarkers(cv_image, board_config["dictionary"])
    if ids is not None:
    #if ids.size > 0:
        cv2.aruco.drawDetectedMarkers(cv_image, corners=markers, ids=ids)
        valid, rotation_vector, translation_vector = cv2.aruco.estimatePoseBoard(markers, ids, boards[0], camera_matrix, distortion_coefficients, None, None)
        if valid > 0:
            cv2.aruco.drawAxis(cv_image, cameraMatrix=camera_matrix, distCoeffs=distortion_coefficients, rvec=rotation_vector, tvec=translation_vector, length=0.03)
            cv2.imshow("Board", cv_image)
            return rotation_vector, translation_vector
        else:
            cv2.imshow("Board", cv_image)
            return numpy.zeros(3), numpy.zeros(3) 
    else:
        cv2.imshow("Board", cv_image)
        return numpy.zeros(3), numpy.zeros(3)

def charuco_pose_estimation(cv_image):
    '''Does poes estimation using the charuco board (chessboard + aruco marker) in the given configuration'''
    corners, ids, _ = cv2.aruco.detectMarkers(cv_image, charuco_config["dictionary"], parameters=params)
    if ids is not None:
        charuco_retval, charuco_corners, charuco_ids = cv2.aruco.interpolateCornersCharuco(corners, ids, cv_image, charuco_boards[0], minMarkers=1)
        cv2.aruco.drawDetectedCornersCharuco(cv_image, charuco_corners, charuco_ids)
        
        retval, rotation_vector, translation_vector = cv2.aruco.estimatePoseCharucoBoard(charuco_corners, charuco_ids, charuco_boards[0],camera_matrix, distortion_coefficients, None, None)# rotation_vector, translation_vector)
        if retval == True:
            cv2.aruco.drawAxis(cv_image, camera_matrix, distortion_coefficients, rotation_vector, translation_vector, 0.03 )
            cv2.imshow("Charuco", cv_image)
            #out.write(cv_image)
            return translation_vector, rotation_vector
        else: 
            cv2.imshow("Charuco", cv_image)
            #out.write(cv_image)
            return numpy.zeros(3), numpy.zeros(3)
    else:
        print("checkpoint_none")
        cv2.imshow("Charuco", cv_image)
        #out.write(cv_image)
        return numpy.zeros(3), numpy.zeros(3)
    #cv2.imshow("Charuco", cv_image)

# %% [markdown]
# ROS Functions

# %%
def image_callback(ros_image):
    '''Callback function for the subscription of the ROS topic /camera/color/image_raw (sensor_msgs Image)'''
    global bridge
    cv_image = bridge.imgmsg_to_cv2(ros_image, "bgr8")
    tvec, rvec = marker_pose_estimation(cv_image)
    #tvec, rvec = board_pose_estimation(cv_image)
    #tvec, rvec = charuco_pose_estimation(cv_image)
    print(tvec, rvec)
    #publish_pose(tvec, rvec)
    cv2.waitKey(1)
    
def calibration_callback(data):
    '''Sets the calibration parameters - camera_matrix and distortion_coefficients - by reading ROS topic /camera/color/cameraInfo'''
    global camera_matrix
    global distortion_coefficients
    camera_matrix = numpy.array(data.K).reshape(3,3)
    distortion_coefficients = numpy.array(data.D).reshape(5,)
    
def run_ros_node():
    '''Initializes the ROS node and setting up Subscriptions and Publishers'''
    rospy.init_node("aruco_estimater", anonymous=True)
    rospy.Subscriber("/camera/color/image_raw", Image, image_callback)
    rospy.Subscriber("/camera/color/camera_info", CameraInfo, calibration_callback)
    rate = rospy.Rate(25)

# %%
def publish_pose(tvec, rvec):
    '''Function that publishes the estimated pose from the charuco board to a ROS topic'''
    command = EstimatedPose()
    command.tx = tvec[0]
    command.ty = tvec[1]
    command.tz = tvec[2]
    command.rx = rvec[0]
    command.ry = rvec[1]
    command.rz = rvec[2]
    pose_publisher.publish(command)

# %% [markdown]
# # Configuration | Instantiation

# %%
bridge = CvBridge()
pose_publisher = rospy.Publisher("/pose_estimation1", EstimatedPose, queue_size=1)
#out = cv2.VideoWriter("200715_charuco_eval_1920_1080_5X5_0.avi", cv2.VideoWriter_fourcc("M", "P", "E", "G"), 30, (640,480))

charuco_config = {
    "squaresX" : 5,
    "squaresY" : 5,
    "squareLength" : 0.0115,
    "markerLength" : 0.008,
    "dictionary" : cv2.aruco.Dictionary_get(cv2.aruco.DICT_7X7_50)
}
board_config = {
    "markersX" : 2,
    "markersY" : 2,
    "markerLength" : 0.02,
    "markerSeparation" : 0.005,
    "dictionary" : cv2.aruco.Dictionary_get(cv2.aruco.DICT_7X7_50)
}

marker_config = cv2.aruco.Dictionary_get(cv2.aruco.DICT_7X7_50)

params = cv2.aruco.DetectorParameters_create()
#charuco_boards = create_charuco_boards(charuco_config)

# P: Projection Camera Matrix (4x3)
# K: Intrinsic Camera Matrix for (distorted) raw images (3x3)
# R: Rectification Matrix (3x3)
# D: Distortion Parameters (5x1)

# %%
boards = create_boards(board_config)
charuco_boards = create_charuco_boards(charuco_config)

# %% [markdown]
# # Main

# %%
def main():
    '''Main Function'''
    run_ros_node()
    
    collected_data = []
    
    try:
        rospy.spin()
    except KeyboardInterrupt:
        print("Shutting down")
    cv2.destroyAllWindows()
    
    #out.release()

# %%
main()
# Out:
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.51321177 0.01091505 0.07198181]]] [[[-0.20845527  0.19453591  0.66573451]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.52132446 0.03846027 0.04726216]]] [[[-0.20781296  0.19370474  0.66133955]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.52132446 0.03846027 0.04726216]]] [[[-0.20781296  0.19370474  0.66133955]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.5212683  0.02809063 0.06396365]]] [[[-0.20826772  0.19412345  0.66302337]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.52305084 0.03469303 0.05438751]]] [[[-0.20985049  0.19532561  0.66787502]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.51960996 0.03189098 0.05679981]]] [[[-0.20627395  0.19253853  0.65663299]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.51960996 0.03189098 0.05679981]]] [[[-0.20627395  0.19253853  0.65663299]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.5212683  0.02809063 0.06396365]]] [[[-0.20826772  0.19412345  0.66302337]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.5212683  0.02809063 0.06396365]]] [[[-0.20826772  0.19412345  0.66302337]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.51960996 0.03189098 0.05679981]]] [[[-0.20627395  0.19253853  0.65663299]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.5212683  0.02809063 0.06396365]]] [[[-0.20826772  0.19412345  0.66302337]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.5212683  0.02809063 0.06396365]]] [[[-0.20826772  0.19412345  0.66302337]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.51960996 0.03189098 0.05679981]]] [[[-0.20627395  0.19253853  0.65663299]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.52129118 0.02108979 0.07527334]]] [[[-0.20489458  0.19452328  0.66463212]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.52278982 0.08690415 0.00751868]]] [[[-0.17211243  0.19489215  0.66395344]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.49814603  0.18268057 -0.09785703]]] [[[-0.11202582  0.19428315  0.67698301]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.51241041  0.25698016 -0.16204157]]] [[[-0.09260779  0.20526048  0.72465116]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.50947959  0.25449459 -0.16010773]]] [[[-0.08478978  0.2051632   0.71937781]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.50505546  0.23763926 -0.1365218 ]]] [[[-0.07210374  0.2061902   0.71397646]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.19467517  1.52492068 -0.71551415]]] [[[-0.14371706 -0.07640686  0.67558501]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.65030611 -1.9716226   0.96672081]]] [[[-0.14847573 -0.07635715  0.6481832 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.22467064  1.73078756 -0.82238058]]] [[[-0.15311162 -0.0709855   0.6138565 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.47570619 -1.92485836  0.84626557]]] [[[-0.1583828  -0.06110624  0.57389918]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.46980621 -1.88574469  0.61115382]]] [[[-0.17283554 -0.04662486  0.5549851 ]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.28946547 -1.62243165 -0.03494169]]] [[[-0.19162906 -0.02179956  0.52204257]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.2107527  -1.51373508 -0.19555592]]] [[[-0.19310858 -0.01272364  0.49942645]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.24822148 -1.53545258 -0.25443873]]] [[[-0.1923172  -0.01033303  0.48805025]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.20998041 -1.49963507 -0.31460843]]] [[[-0.19168866 -0.00768019  0.48100274]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.20279862 -1.4990921  -0.25194825]]] [[[-0.1917523  -0.00922626  0.48273391]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18244161 -1.48127036 -0.22703167]]] [[[-0.19136849 -0.00995324  0.48445444]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.16576408 -1.48074122 -0.17125515]]] [[[-0.1911308  -0.01161113  0.48957028]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.19399473 -1.48329231 -0.14483686]]] [[[-0.1913008  -0.01236002  0.49309618]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18757623 -1.48476073 -0.14365351]]] [[[-0.19194769 -0.01208871  0.49693939]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18245654 -1.48574716 -0.13900601]]] [[[-0.19149268 -0.01225623  0.50120178]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.1733288  -1.48505856 -0.06457043]]] [[[-0.19028251 -0.01188268  0.50361531]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.16846651 -1.4708537  -0.0749226 ]]] [[[-0.19049662 -0.01043567  0.50629125]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.14379053 -1.47949587 -0.10749185]]] [[[-0.18936071 -0.00998307  0.50870919]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.1274728  -1.47296473 -0.07175486]]] [[[-0.18748416 -0.00919337  0.50657207]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.13994979 -1.48642777 -0.06022126]]] [[[-0.18823113 -0.00867699  0.51029333]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.14618561 -1.47438225 -0.05901383]]] [[[-0.18837857 -0.00688067  0.51145626]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.12371702 -1.473813   -0.06135012]]] [[[-0.18749625 -0.00633537  0.50994948]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.13376856 -1.48145322 -0.09622996]]] [[[-0.18850665 -0.00725488  0.51677417]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.17003154 -1.48489955 -0.0541015 ]]] [[[-0.18812718 -0.00937288  0.51889888]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.19309066 -1.51764308 -0.08704118]]] [[[-0.18868696 -0.01411675  0.5243842 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.29212735 -1.58159588 -0.12170952]]] [[[-0.19126126 -0.02557812  0.54048186]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.34349581 -1.63738255 -0.14357285]]] [[[-0.18924973 -0.03836604  0.54287338]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.52819913 -1.74605995 -0.20454727]]] [[[-0.18984115 -0.05544272  0.55968791]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.44820958 1.70671487 0.18991718]]] [[[-0.19013069 -0.07618473  0.58393224]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.37183243  1.68025392 -0.00345945]]] [[[-0.18423507 -0.09314388  0.58851964]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.29472885  1.64486134 -0.07011697]]] [[[-0.18461594 -0.10348946  0.60324456]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.1732646   1.50343553 -0.13608102]]] [[[-0.18745785 -0.10583074  0.60314986]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.07960588  1.36326646 -0.14329683]]] [[[-0.19471871 -0.1058999   0.611148  ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.04298878  1.21814647 -0.14090284]]] [[[-0.20506784 -0.10176385  0.62491659]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.95249961  1.08060979 -0.16109202]]] [[[-0.21340171 -0.09131108  0.63076915]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.37699526 1.31798882 0.34696456]]] [[[-0.19425654  0.00292643  0.5819368 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.71095798 1.75361869 0.6620881 ]]] [[[-0.17768345 -0.01178345  0.55400651]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.48151851 1.64952695 0.59518913]]] [[[-0.16360047 -0.01869852  0.52974822]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.48936131 1.75464648 0.73186969]]] [[[-0.15299441 -0.02150156  0.510296  ]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.10988432 1.62104085 1.06320216]]] [[[-0.12054313 -0.0021016   0.42555173]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.01444691 1.51584433 1.12176244]]] [[[-0.12895178  0.00960133  0.43722007]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.9769727  1.43206272 0.91624624]]] [[[-0.13781231  0.0223034   0.46564632]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[1.91606603 1.2926749  0.54014377]]] [[[-0.13702944  0.03759326  0.49169446]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.3104984   0.92022449 -0.38086225]]] [[[-0.17122519  0.10300463  0.55327727]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.39916528  0.93331358 -0.40493573]]] [[[-0.17160322  0.10392138  0.557969  ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.27226491  0.96547865 -0.378622  ]]] [[[-0.17184587  0.09110315  0.55229874]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.9976929   1.13259147 -0.10333469]]] [[[-0.16314862  0.03305176  0.52686457]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 1.96496908  1.18106257 -0.02955536]]] [[[-0.15562224  0.01648521  0.51757068]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.01598979 1.30189522 0.08832791]]] [[[-0.14888834  0.0033579   0.5144437 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[2.10527011 1.43742708 0.17024696]]] [[[-0.14292478 -0.01453099  0.52576967]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.38912952 -2.1673855  -1.10294933]]] [[[-0.10550388 -0.06879148  0.42200789]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.16785095 -1.92234999  0.13070292]]] [[[-0.11896912 -0.0418718   0.43096412]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.21837452 -1.88412458  0.07184555]]] [[[-0.12907709 -0.01690401  0.42762034]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18855047 -1.86596094 -0.06065523]]] [[[-0.13485698  0.00256429  0.4195726 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.30120017 -1.94737315 -0.13415374]]] [[[-0.13725959  0.02006745  0.40864646]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.29726602 -1.92738109 -0.17964807]]] [[[-0.1366904   0.03698263  0.39371277]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.17029294 -2.00562836 -0.23628096]]] [[[-0.08661534  0.10457022  0.33684921]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.09506438 -1.9384622  -0.35547237]]] [[[-0.0872552   0.11129398  0.32890526]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.07837684 -1.84495886 -0.45235973]]] [[[-0.0910375   0.12050558  0.32372937]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.00832937 -1.7993018  -0.44685432]]] [[[-0.09118835  0.11750831  0.32470126]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.00828954 -1.77586396 -0.41305409]]] [[[-0.09226687  0.11750744  0.32725412]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.03163691 -1.76786258 -0.44236392]]] [[[-0.09307136  0.11856485  0.32417429]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.09082102 -1.75863795 -0.43690407]]] [[[-0.0943978   0.11807049  0.32046021]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.12787485 -1.75657894 -0.43173537]]] [[[-0.09521543  0.1168269   0.31883531]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.10278871 -1.76997686 -0.39585939]]] [[[-0.09536867  0.11462058  0.31789188]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.13214723 -1.77666521 -0.38353429]]] [[[-0.09705518  0.11428257  0.31670838]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.17331622 -1.76665064 -0.40147472]]] [[[-0.09855962  0.11687972  0.31679827]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18539142 -1.75507714 -0.43355713]]] [[[-0.09878513  0.11928372  0.31284182]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18610564 -1.73417862 -0.42443446]]] [[[-0.09887426  0.12089799  0.31084177]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.19008745 -1.74134793 -0.40885232]]] [[[-0.0987392   0.12308931  0.31185661]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18139779 -1.75117676 -0.42346903]]] [[[-0.09878579  0.12475968  0.31101312]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.18806389 -1.76230364 -0.39936833]]] [[[-0.10066589  0.12435298  0.31186418]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.1788098  -1.78325542 -0.36292175]]] [[[-0.10159915  0.12216303  0.31454108]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.17897406 -1.80265234 -0.3498917 ]]] [[[-0.10333342  0.11946183  0.31695549]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.17455253 -1.82509594 -0.32491365]]] [[[-0.1047514   0.11558464  0.31565963]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.17108122 -1.84448585 -0.28947583]]] [[[-0.1053549   0.11193801  0.31417644]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.20165871 -1.85436279 -0.13151305]]] [[[-0.1031856   0.09133529  0.31438583]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.13628369 -1.84434627 -0.07799106]]] [[[-0.10039059  0.08535057  0.32155912]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.14337658 -1.85292913  0.07523559]]] [[[-0.09611737  0.08075005  0.33446084]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.10779395 -1.92378645  0.27944468]]] [[[-0.08349884  0.0694074   0.34862506]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.93311003 -2.21155434 -0.50405085]]] [[[-0.1163969   0.08890911  0.36579297]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.92945986 -2.10052335 -0.60492446]]] [[[-0.11619313  0.08415831  0.36206365]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.91870123 -2.0029362  -0.68582049]]] [[[-0.11583178  0.07820142  0.35773256]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.9253522  -1.92610344 -0.71180013]]] [[[-0.11635985  0.07246032  0.35457726]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.93181544 -1.83873877 -0.77082715]]] [[[-0.11601973  0.06669529  0.3517152 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.95733723 -1.78153302 -0.75835285]]] [[[-0.11612589  0.05954222  0.35211361]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97378726 -1.7318494  -0.76611856]]] [[[-0.1155017   0.05278229  0.34966203]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97616764 -1.65378428 -0.81712123]]] [[[-0.11485885  0.04884425  0.34791641]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97665289 -1.60778449 -0.83286664]]] [[[-0.11432689  0.04436198  0.34989089]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.98237752 -1.60997071 -0.8008784 ]]] [[[-0.11501872  0.03818052  0.35613778]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97813607 -1.59828062 -0.77830532]]] [[[-0.11490343  0.03280475  0.35793883]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97897306 -1.58899558 -0.78970222]]] [[[-0.11536453  0.0288218   0.36115715]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97155213 -1.53746201 -0.82202209]]] [[[-0.11578853  0.02757985  0.36558151]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.97079135 -1.46931111 -0.81733004]]] [[[-0.1165592   0.02721602  0.37009607]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.9229784  -1.4056794  -0.81295452]]] [[[-0.1172144   0.02534095  0.37275939]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.93071718 -1.35736668 -0.78335191]]] [[[-0.1189822   0.02369243  0.37818633]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.90807727 -1.27060375 -0.83288995]]] [[[-0.11896364  0.02376661  0.37261888]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.90449372 -1.21921016 -0.84148497]]] [[[-0.12070334  0.02417462  0.37358506]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.88516725 -1.1325332  -0.90529157]]] [[[-0.12269485  0.02652896  0.37329018]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-1.88411279 -1.04503232 -0.88780913]]] [[[-0.12477398  0.02814391  0.37489112]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.47774021 -0.21286788 -1.28210166]]] [[[-0.16538176  0.01913761  0.37911786]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.66069874 -0.05425137 -1.21815302]]] [[[-0.16514381  0.02831612  0.3963457 ]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.91708748  0.15673916 -1.17493668]]] [[[-0.17163816  0.02550838  0.42847119]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.69449979 -0.24101346  0.95230192]]] [[[-0.17605989  0.01888184  0.45500726]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.75007221 -0.21431554  0.88696322]]] [[[-0.17807792  0.01903625  0.46632683]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79976869 -0.19515954  0.87446409]]] [[[-0.17972019  0.02374406  0.47685677]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.93774714 -0.13138049  0.68800737]]] [[[-0.18200432  0.02828806  0.50223131]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.89978528 -0.12887393  0.55688034]]] [[[-0.18420408  0.02963028  0.51451667]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.86120648 -0.07102725  0.47780622]]] [[[-0.17848953  0.02655501  0.52453465]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.99308212 -0.04035829  0.49026124]]] [[[-0.17654391  0.02677371  0.52143974]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.98385767 -0.06456693  0.61588061]]] [[[-0.17417587  0.03462012  0.51280836]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 3.25604322 -0.03143724  0.48484067]]] [[[-0.17312443  0.04418473  0.50194603]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.91329704 -0.11965733  0.42978701]]] [[[-0.17348885  0.04564424  0.50171461]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83008178 -0.13292414  0.40809084]]] [[[-0.17124809  0.04525552  0.49388994]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.86812052 -0.12325653  0.38342951]]] [[[-0.17260345  0.04625015  0.49776712]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82819832 -0.13280415  0.41024992]]] [[[-0.17124921  0.0460633   0.49390378]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.80544887 -0.12294379  0.38779427]]] [[[-0.17092634  0.04623581  0.49411246]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81482014 -0.11278475  0.38049275]]] [[[-0.1723348   0.04618842  0.49827522]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.87470628 -0.10596704  0.42239504]]] [[[-0.17308242  0.04594932  0.50030716]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82975241 -0.11368742  0.41572481]]] [[[-0.17264301  0.04568597  0.49455394]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83061915 -0.13287282  0.41501303]]] [[[-0.17298211  0.04608219  0.49431201]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.76207437 -0.13740076  0.44233141]]] [[[-0.17159107  0.04598568  0.48830772]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82992911 -0.13277635  0.41961969]]] [[[-0.17385067  0.04690047  0.49452997]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.7953719  -0.11011562  0.40881913]]] [[[-0.17358598  0.04699245  0.49292609]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79034484 -0.10996518  0.43052696]]] [[[-0.1734949   0.04738842  0.49270192]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79400854 -0.12277326  0.44504258]]] [[[-0.17297551  0.04632712  0.49098789]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82265074 -0.11134936  0.39028708]]] [[[-0.17352925  0.04641132  0.49263841]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.86342502 -0.06772839  0.47724748]]] [[[-0.16581323  0.02875354  0.47737695]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84506324 -0.08332363  0.52271714]]] [[[-0.16673569  0.03089275  0.47804104]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.73803749 -0.10780933  0.49532183]]] [[[-0.16784673  0.03035047  0.48114015]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.73549684 -0.08158845  0.48688019]]] [[[-0.16890779  0.02817639  0.4841151 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.76142744 -0.09166027  0.47464274]]] [[[-0.17068806  0.02939645  0.48811835]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82100308 -0.0850402   0.48352449]]] [[[-0.17060266  0.03088064  0.48782787]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.77134727 -0.10277656  0.49687482]]] [[[-0.17002086  0.03001324  0.48727375]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.73600439 -0.09032696  0.49195832]]] [[[-0.16881692  0.02877188  0.48725629]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.76439703 -0.09357329  0.49868602]]] [[[-0.16745922  0.02980046  0.48323708]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.76296477 -0.10103576  0.514502  ]]] [[[-0.16681382  0.03314298  0.48035843]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.72184671 -0.11737992  0.49116705]]] [[[-0.16792387  0.03449389  0.48345006]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.71583375 -0.09679899  0.46507636]]] [[[-0.16902896  0.03373255  0.48789614]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.7520674  -0.09089675  0.47564154]]] [[[-0.16894143  0.03258049  0.48761777]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.75833011 -0.10218694  0.5163645 ]]] [[[-0.16899001  0.03359084  0.48654731]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.73657486 -0.10131611  0.52188233]]] [[[-0.16891711  0.03256707  0.48632958]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.69948892 -0.08994521  0.50185131]]] [[[-0.16885015  0.03092383  0.48605158]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.70613857 -0.0980389   0.49886967]]] [[[-0.16833831  0.03151091  0.48356894]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.73222965 -0.09236203  0.5275144 ]]] [[[-0.16806434  0.03234128  0.48271827]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.74481844 -0.09750398  0.45394781]]] [[[-0.16775423  0.03271775  0.48202455]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.75915741 -0.09891316  0.48517122]]] [[[-0.1683505   0.03276951  0.48489533]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.78435254 -0.09424079  0.49355044]]] [[[-0.16749915  0.03160778  0.48334218]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.77583077 -0.0757044   0.5365232 ]]] [[[-0.16617279  0.03061159  0.47959567]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.74475723 -0.08200779  0.51718954]]] [[[-0.16637694  0.03017133  0.48024345]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.74160459 -0.08202775  0.53118123]]] [[[-0.16626132  0.03056619  0.47989203]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.75800652 -0.07478956  0.50593141]]] [[[-0.16786175  0.03177786  0.48330507]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79195476 -0.0647653   0.49507817]]] [[[-0.1679047   0.03220245  0.4813414 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85760818 -0.0538781   0.4725769 ]]] [[[-0.16937305  0.0325177   0.48559996]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.86565449 -0.05112149  0.47967956]]] [[[-0.16461157  0.03432665  0.46785968]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.90835077 -0.05873588  0.51520563]]] [[[-0.16474682  0.03746084  0.46712416]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85898895 -0.06174872  0.54594909]]] [[[-0.16576885  0.03806161  0.47210949]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84849144 -0.07373552  0.52636356]]] [[[-0.16673688  0.03827976  0.47469942]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.89496279 -0.06081718  0.51934584]]] [[[-0.16812649  0.03921272  0.47874831]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84834577 -0.07008117  0.49348121]]] [[[-0.16702999  0.03979776  0.47357149]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83426359 -0.08174023  0.50245037]]] [[[-0.16782153  0.03963166  0.47565286]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.78958258 -0.08167914  0.46838252]]] [[[-0.16724042  0.03929928  0.47289751]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79796833 -0.07358709  0.5160926 ]]] [[[-0.16690722  0.03911655  0.47195042]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.8295186  -0.07392501  0.48583986]]] [[[-0.1670837   0.0389674   0.47241432]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.78255767 -0.08078185  0.51478052]]] [[[-0.16641361  0.03942521  0.46961121]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79805949 -0.08891694  0.4817751 ]]] [[[-0.16668972  0.03945277  0.47039939]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84947443 -0.07003258  0.49638055]]] [[[-0.16785834  0.03980477  0.47376009]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84947443 -0.07003258  0.49638055]]] [[[-0.16785834  0.03980477  0.47376009]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79805949 -0.08891694  0.4817751 ]]] [[[-0.16668972  0.03945277  0.47039939]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84947443 -0.07003258  0.49638055]]] [[[-0.16785834  0.03980477  0.47376009]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84947443 -0.07003258  0.49638055]]] [[[-0.16785834  0.03980477  0.47376009]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85369206 -0.06610382  0.56602301]]] [[[-0.16797145  0.03925591  0.47376678]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85369206 -0.06610382  0.56602301]]] [[[-0.16797145  0.03925591  0.47376678]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84789665 -0.07360531  0.53447431]]] [[[-0.16837304  0.0390662   0.47500425]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83047657 -0.07393387  0.48865574]]] [[[-0.16790984  0.03897377  0.47260126]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81151595 -0.08098387  0.50727249]]] [[[-0.16649     0.03889184  0.46982179]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.90228678 -0.05951636  0.52339348]]] [[[-0.16764147  0.03872123  0.47310333]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.90228678 -0.05951636  0.52339348]]] [[[-0.16764147  0.03872123  0.47310333]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83105399 -0.07126352  0.45034028]]] [[[-0.16727413  0.03815429  0.47093897]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85321959 -0.07260873  0.53521719]]] [[[-0.16707088  0.03857041  0.46927317]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85321959 -0.07260873  0.53521719]]] [[[-0.16707088  0.03857041  0.46927317]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81239513 -0.08102178  0.51009375]]] [[[-0.1673115   0.03889808  0.47000724]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81239513 -0.08102178  0.51009375]]] [[[-0.1673115   0.03889808  0.47000724]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81239513 -0.08102178  0.51009375]]] [[[-0.1673115   0.03889808  0.47000724]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82120084 -0.06973389  0.5253921 ]]] [[[-0.16636953  0.03867462  0.46752133]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82120084 -0.06973389  0.5253921 ]]] [[[-0.16636953  0.03867462  0.46752133]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82120084 -0.06973389  0.5253921 ]]] [[[-0.16636953  0.03867462  0.46752133]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82120084 -0.06973389  0.5253921 ]]] [[[-0.16636953  0.03867462  0.46752133]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82694467 -0.0698988   0.50001658]]] [[[-0.16653201  0.03829808  0.46797198]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81896821 -0.07329629  0.55707794]]] [[[-0.16604111  0.03793645  0.46848827]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81596012 -0.08116863  0.50371869]]] [[[-0.16651507  0.03735846  0.46989014]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85472936 -0.07271969  0.53014667]]] [[[-0.16627083  0.03779944  0.46914643]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84698314 -0.07671111  0.57248074]]] [[[-0.16665547  0.03781976  0.46997393]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85472936 -0.07271969  0.53014667]]] [[[-0.16627083  0.03779944  0.46914643]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85472936 -0.07271969  0.53014667]]] [[[-0.16627083  0.03779944  0.46914643]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82257861 -0.06980763  0.52077331]]] [[[-0.1655674   0.03790609  0.46737924]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82257861 -0.06980763  0.52077331]]] [[[-0.1655674   0.03790609  0.46737924]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82257861 -0.06980763  0.52077331]]] [[[-0.1655674   0.03790609  0.46737924]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82484891 -0.06988861  0.51909463]]] [[[-0.16558123  0.03714363  0.46741825]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82484891 -0.06988861  0.51909463]]] [[[-0.16558123  0.03714363  0.46741825]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83348439 -0.06223571  0.54719837]]] [[[-0.16527297  0.037343    0.46648124]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85472936 -0.07271969  0.53014667]]] [[[-0.16627083  0.03779944  0.46914643]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81896821 -0.07329629  0.55707794]]] [[[-0.16604111  0.03793645  0.46848827]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.8282354  -0.06995658  0.49545431]]] [[[-0.1657257   0.03752868  0.46781819]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83348439 -0.06223571  0.54719837]]] [[[-0.16527297  0.037343    0.46648124]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.8282354  -0.06995658  0.49545431]]] [[[-0.1657257   0.03752868  0.46781819]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81896821 -0.07329629  0.55707794]]] [[[-0.16604111  0.03793645  0.46848827]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82132563 -0.08143884  0.4583691 ]]] [[[-0.16597827  0.03826153  0.46721797]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82463292 -0.06983375  0.50184134]]] [[[-0.16651893  0.03906141  0.46793653]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81223657 -0.07799827  0.47617068]]] [[[-0.16671565  0.03885336  0.46849953]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81686738 -0.08002916  0.5080406 ]]] [[[-0.16523003  0.03840204  0.46423221]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85873259 -0.06916836  0.49029137]]] [[[-0.16577895  0.03776885  0.46795726]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83511262 -0.06229929  0.54250482]]] [[[-0.16447958  0.03657727  0.46636223]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.79064259 -0.08003361  0.52368605]]] [[[-0.16344823  0.03626558  0.46341489]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82713848 -0.06633943  0.57735337]]] [[[-0.16405206  0.03659031  0.46700817]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.83899243 -0.07001332  0.55474528]]] [[[-0.16435254  0.03720942  0.46926108]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81911488 -0.07330297  0.54626656]]] [[[-0.16361783  0.03715669  0.46802896]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81133688 -0.08439196  0.53105687]]] [[[-0.16457453  0.03737542  0.47061822]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81329971 -0.08102923  0.49540213]]] [[[-0.1640539   0.03734162  0.46933443]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.78696485 -0.08078081  0.50186525]]] [[[-0.16399427  0.03711036  0.4691725 ]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.80213187 -0.07369897  0.50248767]]] [[[-0.16447594  0.0367899   0.47150735]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82876027 -0.06312622  0.53880682]]] [[[-0.16491665  0.03704056  0.47183001]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.86051395 -0.0618653   0.54099271]]] [[[-0.16496676  0.03728633  0.47199062]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.78325992 -0.08076973  0.52417353]]] [[[-0.16467356  0.03749533  0.46895104]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.85898895 -0.06174872  0.54594909]]] [[[-0.16576885  0.03806161  0.47210949]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82170265 -0.07338073  0.53056352]]] [[[-0.16539852  0.03831889  0.46881555]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82170265 -0.07338073  0.53056352]]] [[[-0.16539852  0.03831889  0.46881555]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.82166517 -0.06979634  0.5178402 ]]] [[[-0.16475171  0.03790015  0.46719727]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81692221 -0.06549205  0.53802871]]] [[[-0.16455904  0.03653312  0.46532335]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.86165224 -0.05361975  0.52920633]]] [[[-0.16463949  0.03619127  0.46358939]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.88434995 -0.05268724  0.57590272]]] [[[-0.16372512  0.03505985  0.46000431]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.84989751 -0.06066587  0.56481987]]] [[[-0.16192841  0.03307463  0.45512941]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.81561341 -0.0613954   0.51429878]]] [[[-0.1607729   0.02982787  0.45290647]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[ 2.80582612 -0.05501178  0.55132991]]] [[[-0.15958876  0.0257586   0.45154838]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.60136666 -0.14668441 -1.13645066]]] [[[-0.02645899  0.04406937  0.29822298]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.55978816 -0.11614539 -1.11687492]]] [[[-0.0303109   0.05270303  0.29106072]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.54311537 -0.1282237  -1.10739403]]] [[[-0.03101299  0.05280664  0.28885591]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.5922039  -0.10844396 -1.10502798]]] [[[-0.03371927  0.05310565  0.28582254]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.59295853 -0.10801036 -1.10297848]]] [[[-0.03325279  0.05310514  0.28579682]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.58904948 -0.09966248 -1.11048099]]] [[[-0.03290027  0.05331838  0.28565028]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.61170645 -0.08972236 -1.12033857]]] [[[-0.03287611  0.0541974   0.28552449]]]
# [[0]]
# if ids is not None
# for marker in markers
# [[[-2.67760641 -0.0492623  -1.14997666]]] [[[-0.03198726  0.05596962  0.28480374]]]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# ...
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]
# None
# else
# [0. 0. 0.] [0. 0. 0.]

# %%
# ?cv2.aruco.estimatePoseSingleMarkers

# %%
# ?cv2.aruco.estimatePoseBoard

# %%
# ?cv2.aruco.drawDetectedMarkers

# %%
# ?cv2.aruco.detectMarkers

# %%
# ?cv2.aruco.drawMarker
