# %%
import os
import numpy
import json

# %%
fts = []
for i in range(50):
    ft = numpy.random.normal(0, 20, 6)
    fts.append(ft)

# %%
fts
# Out:
# [array([ 10.39371659,  -3.33359948, -18.30231272,  15.96103506,
#           0.43032999,   3.0252899 ]),
#  array([ 18.2082256 , -27.59178567,   7.43001698,   6.94022194,
#           5.6485351 ,  29.06168425]),
#  array([  6.91340693,  12.64248247,  17.34029861, -20.8574799 ,
#          -9.59827296,  -1.16512282]),
#  array([-10.19579373,   2.63134671,  -4.32669378,  14.77873315,
#          15.96201433,   7.79351464]),
#  array([43.50243676, -2.64642587, 13.82459861, 10.10753916, 19.06415534,
#          8.10476966]),
#  array([-12.51006406,  -7.14221731,  -5.4171186 ,  16.97500874,
#          -9.43360522,  22.76128613]),
#  array([ -5.46741288,  -5.39964209,  -6.15568296, -27.05694881,
#         -25.14178396, -19.34523012]),
#  array([-11.82637   ,  11.54083781,   2.56875983,  28.84319044,
#         -17.03957593,  22.9448741 ]),
#  array([ -0.5150736 ,  25.89729932,   0.24369021,   0.06239391,
#         -19.46289708,  -9.41928989]),
# ...

# %%
fts_dict = {
    "fx" : 
    "fy" :
    "fz" : 
}
